# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 1) Write a program to load the above given dataset, and print
# top 5 and last 5 rows, and find the no. of row and no.
# columns in the dataset.

# %%
df=pd.read_csv("tip_data.csv")

print(df.head(6))
print(df.tail(6))

rows, columns=df.shape


print("rows=", rows)
print("coloumns=",columns)
# Out:
#    total_bill   tip  gender smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
#      total_bill   tip  gender smoker   day    time  size
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
# rows= 244
# coloumns= 7

# %% [markdown]
# 2) Write a program to find no. of for entry for each “day” and
# plot the bar plot, where on a x axis you will plot name of
# days, and on a y axis no. of entry

# %%
df["day"].value_counts()

days=list(df['day'].value_counts().keys())
entries=list(df['day'].value_counts().values)

plt.bar(days,entries)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# 3) Find out the relationship between “total bill” and “tip” using
# scatter plot

# %%
plt.scatter(x= df['total_bill'],y= df['tip'] )

# %% [markdown]
# 4) Check out the distribution of ‘tip’ and ‘total_bill’ using
# histogram.

# %%
plt.hist(df["total_bill"],edgecolor='black',color='orange')
plt.hist(df["tip"],edgecolor='black',color='blue')
plt.show()

# %% [markdown]
# 5) Find total sells for each day by ‘total_bill’ using group by and
# represent the data into graphical way, where on x axis will
# have ‘day names’ and on a y axis will have ‘total_price’ for
# each day

# %%
group= df.groupby("day")['total_bill'].sum()

group.plot(x='day',y='total_price')
# Out:
# <Axes: xlabel='day'>

# %% [markdown]
# 6) Try to build “pie” plot on ‘smoker’ column, where represent
# the percentage of smoker “yes” and “No”.

# %%
counts = df['smoker'].value_counts()
plt.pie(counts,labels=counts.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x12387f3b710>,
#   <matplotlib.patches.Wedge at 0x12387f44250>],
#  [Text(-0.4012471747910624, 1.0242073543585746, 'No'),
#   Text(0.4012470788978477, -1.024207391926042, 'Yes')])
